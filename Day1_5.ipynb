# %% [markdown]
# <a href="https://colab.research.google.com/github/Jefrina-V/VAC-Artificial-Intelligence-and-Data-Science-/blob/main/Day1_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#stemming
#porter stemmer
import nltk
from nltk.stem import *
p_stemmer=PorterStemmer()

# %%
words = ['run','runner','running','ran','runs','easily','fairly']

# %%
for word in words:
  print(word+'---->'+p_stemmer.stem(word))
# Out:
# run---->run
# runner---->runner
# running---->run
# ran---->ran
# runs---->run
# easily---->easili
# fairly---->fairli

# %%
#snowball stemmer
from nltk.stem.snowball import SnowballStemmer

# %%
s_stemmer=SnowballStemmer(language='english')

# %%
words = ['generous','generation','generously','generate']
for word in words:
    print(word+'---->'+s_stemmer.stem(word))
# Out:
# generous---->generous
# generation---->generat
# generously---->generous
# generate---->generat

# %%
import nltk
from nltk.stem import PorterStemmer
p_stemmer = PorterStemmer()

print('Porter stemmer:')
# Redefining words here to ensure it's available, as the error indicated 'words' was not defined.
words = ['generous','generation','generously','generate']
for word_item in words:
  print(word_item+'---->'+p_stemmer.stem(word_item))
# Out:
# Porter stemmer:
# generous---->gener
# generation---->gener
# generously---->gener
# generate---->gener

# %%
from nltk.stem.snowball import SnowballStemmer
s_stemmer = SnowballStemmer(language='english')
print('snowball stemmer:')
for word_item in words:
  print(word_item+'---->'+s_stemmer.stem(word_item))
# Out:
# snowball stemmer:
# generous---->generous
# generation---->generat
# generously---->generous
# generate---->generat

# %%
phrase = 'I am going to go to dubai in this summer holidays'
for word in phrase.split():
  print(word+'---->'+p_stemmer.stem(word))
# Out:
# I---->i
# am---->am
# going---->go
# to---->to
# go---->go
# to---->to
# dubai---->dubai
# in---->in
# this---->thi
# summer---->summer
# holidays---->holiday
