# %% [markdown]
# <a href="https://colab.research.google.com/github/Jefrina-V/VAC-Artificial-Intelligence-and-Data-Science-/blob/main/Day1_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -U spacy

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 98.9 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

#create a doc object
doc=nlp(u'Tesla is looking at buying U.S. startup for $6 million')
for token in doc:
  print(token.text,token.pos_,token.dep_)
# Out:
# Tesla PROPN nsubj
# is AUX aux
# looking VERB ROOT
# at ADP prep
# buying VERB pcomp
# U.S. PROPN dobj
# startup VERB advcl
# for ADP prep
# $ SYM quantmod
# 6 NUM compound
# million NUM pobj

# %%
nlp.pipeline
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x7a2655114d70>),
#  ('tagger', <spacy.pipeline.tagger.Tagger at 0x7a26551145f0>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x7a2655148120>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x7a26569b2a90>),
#  ('lemmatizer',
#   <spacy.lang.en.lemmatizer.EnglishLemmatizer at 0x7a2653ea1ad0>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x7a2656569e70>)]

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
doc2=nlp(u"Tesla isn't looking into startups anymore.")
for token in doc2:
  print(token.text,token.pos_,token.dep_)
# Out:
# Tesla PROPN nsubj
# is AUX aux
# n't PART neg
# looking VERB ROOT
# into ADP prep
# startups NOUN pobj
# anymore ADV advmod
# . PUNCT punct

# %%
doc2
# Out:
# Tesla isn't looking into startups anymore.

# %%
doc2[0]
# Out:
# Tesla

# %%
doc2[0].pos_
# Out:
# 'PROPN'

# %%
doc2[0].dep_
# Out:
# 'nsubj'

# %%
spacy.explain('nsubj')
# Out:
# 'nominal subject'

# %%
print(doc2[4].text)
print(doc2[4].lemma_)
print(doc2[4].pos_)
print(doc2[4].tag_ +'/'+ spacy.explain(doc2[4].tag_))
# Out:
# into
# into
# ADP
# IN/conjunction, subordinating or preposition

# %%
#word shapes....
print(doc2[0].text+': '+doc[0].shape_)
print(doc2[5].text+': '+doc[5].shape_)
# Out:
# Tesla: Xxxxx
# startups: X.X.

# %%
print(doc2[0].is_alpha)
print(doc2[0].is_stop)
# Out:
# True
# False

# %%
#span.....
doc3 = nlp("""Although commonly attributed to John Lennon from his song "Beautiful Boy", the phrase "Life is what happens to us while we are making other plans" was written by cartoonist Allen Saunders and published in Reader's Digest in 1957, when Lennon was 17.""")

# %%
life_quote = doc3[16:30]
print(life_quote)
# Out:
# "Life is what happens to us while we are making other plans"

# %%
type(life_quote)
# Out:
# spacy.tokens.span.Span

# %%
doc4 = nlp(u'This is the first dentence.This is another sentence.This is the last sentence.')

# %%
for sent in doc4.sents:
  print(sent)
# Out:
# This is the first dentence.
# This is another sentence.
# This is the last sentence.

# %%
doc4[6].is_sent_start
# Out:
# True
