# %% [markdown]
# <a href="https://colab.research.google.com/github/Jefrina-V/VAC-Artificial-Intelligence-and-Data-Science-/blob/main/Day_1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name='Jefrina'
print('My name is {var}.'.format(var=name))
# Out:
# My name is Jefrina.

# %%
#using f-string.....
name="Jefrina"
course="AI"
message=f"My name is {name} and I am learning {course}."
print(message)
# Out:
# My name is Jefrina and I am learning AI.

# %%
#!r-> string representation
name='Jefrina'
print(f'My name is{name!r}')
# Out:
# My name is'Jefrina'

# %%
#dictionary....
d = {'a':123,'b':456}
print(f"Address: {d['a']} Main street")
# Out:
# Address: 123 Main street

# %%
#list...
library=[('Author','Topic','pages'),('Twain','Rafting',601),('Feyman','physics',95),('Hamiltonian','Mythology',144)]
for book in library:
    print(f'{book[0]:{10}} {book[1]:{10}} {book[2]:.>{7}}' )
# Out:
# Author     Topic      ..pages
# Twain      Rafting    ....601
# Feyman     physics    .....95
# Hamiltonian Mythology  ....144

# %%
#datetime...
from datetime import datetime
today=datetime(year=2018, month=1, day=27)
print(f'{today:%B %d %Y}')
# Out:
# January 27 2018

# %%
#creating a file....
with open("LOYOLA.txt", "w") as file:
    file.write("HHello, this is a quick test file.")
    file.write("This is the second line of the file.")

# %%
my_file=open('LOYOLA.txt')

# %%
my_file.seek(1)
my_file.readlines()
# Out:
# ['Hello, this is a quick test file.This is the second line of the file.']

# %%
my_file.close()

# %%
my_file=open('LOYOLA.txt','w+')

# %%
my_file.write('This is a new first line')
# Out:
# 24

# %%
my_file.seek(0)
my_file.read()
# Out:
# 'This is a new first line'

# %% [markdown]
# my_file.close()

# %%
my_file.close()

# %%
my_file=open('LOYOLA.txt','a+')
my_file.write('\nThis line is being appended to test.txt')
my_file.write('\nAnd another line here.')
# Out:
# 23

# %%
my_file.seek(0)
print(my_file.read())
# Out:
# This is a new first line
# This line is being appended to test.txt
# And another line here.

# %%
with open('LOYOLA.txt','r') as txt:
    first_line = txt.readlines()[0]

print(first_line)
# Out:
# This is a new first line

# %%
with open('LOYOLA.txt','r') as txt:
    for line in txt:
        print(line, end='')
# Out:
# This is a new first line
# This line is being appended to test.txt
# And another line here.
