# %% [markdown]
# <a href="https://colab.research.google.com/github/Jefrina-V/VAC-Artificial-Intelligence-and-Data-Science-/blob/main/Day1_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
mystring = '"We\'re moving to L.A.!"'
print(mystring)
# Out:
# "We're moving to L.A.!"

# %%
doc = nlp(mystring)
for token in doc:
  print(token.text,end=' | ')
# Out:
# " | We | 're | moving | to | L.A. | ! | " |

# %%
doc3 = nlp(u'A 5km NYC cab ride costs $10.30')
for t in doc3:
  print(t)
# Out:
# A
# 5
# km
# NYC
# cab
# ride
# costs
# $
# 10.30

# %%
doc4 = nlp(u"Let's visit St. Louis in the U.S. next year.")
for t in doc4:
           print(t)
# Out:
# Let
# 's
# visit
# St.
# Louis
# in
# the
# U.S.
# next
# year
# .

# %%
len(doc)
# Out:
# 8

# %%
len(doc.vocab)
# Out:
# 783

# %%
doc5 = nlp(u"It is better to give than to receive.")
#Retrieve third token
doc5[2]
# Out:
# better

# %%
doc5[2:5]
# Out:
# better to give

# %%
doc5[-4:]
# Out:
# than to receive.

# %%
doc6 = nlp(u'My dinner was horrible.')
doc7 = nlp(u'Your dinner was delicious.')

# %%
new_text = f"{doc6[0].text} {doc6[1].text} {doc6[2].text} {doc7[3].text}"
doc6_modified = nlp(new_text)
print(doc6_modified)
# Out:
# My dinner was delicious

# %%
doc8 = nlp(u'Apple to build a Hong Kong factory for $6 million')
for token in doc8:
  print(token.text, end=' | ')
print('\n----')
for ent in doc8.ents:
  print(ent.text+' - '+ent.label_+' - '+str(spacy.explain(ent.label_)))
# Out:
# Apple | to | build | a | Hong | Kong | factory | for | $ | 6 | million |
# ----
# Apple - ORG - Companies, agencies, institutions, etc.
# Hong Kong - GPE - Countries, cities, states
# $6 million - MONEY - Monetary values, including unit

# %%
len(doc8.ents)
# Out:
# 3

# %%
doc9=nlp(u"Autonomous cars shift insurance liability toward manufacturers.")
for chunk in doc9.noun_chunks:
  print(chunk.text)
# Out:
# Autonomous cars
# insurance liability
# manufacturers

# %%
doc10 = nlp(u"Red cars do not carry higher insurance rates.")
for chunk in doc10.noun_chunks:
  print(chunk.text)
# Out:
# Red cars
# higher insurance rates

# %%
doc11 = nlp(u"He was a one-eyed, one-horned, flying, purple people-eater.")
for chunk in doc11.noun_chunks:
  print(chunk.text)
# Out:
# He
# a one-eyed, one-horned, flying, purple people-eater

# %%
from spacy import displacy
doc = nlp(u'Apple is going to build a U.K. factory for $6 million.')
displacy.render(doc,style='dep',jupyter=True,options={'distance':110})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="810b330fd7374956a45a366fee4452a1-0" class="displacy" width="1370" height="357.0" direction="ltr" style="max-width: none; height: 357.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Apple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
# ...

# %%
doc = nlp(u"Over the last quarter Apple sold nearly 20 thousand iPods for a profit of $6 million.'ipods for a profit of $6 million.")
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the last quarter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sold
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly 20 thousand
# ...
